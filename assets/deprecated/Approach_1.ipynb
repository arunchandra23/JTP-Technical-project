# %%
import os
import cv2
import numpy as np
from skimage.feature import local_binary_pattern
from qdrant_client import QdrantClient
from concurrent.futures import ProcessPoolExecutor
from qdrant_client.http import models
import uuid as uuidpy
from skimage.feature import hog


COLOR_HIST_BINS = 32
LBP_POINTS = 24
LBP_RADIUS = 3
HOG_PIXELS_PER_CELL = (8, 8)
HOG_CELLS_PER_BLOCK = (2, 2)
HOG_ORIENTATIONS = 9

COLOR_FEATURE_SIZE = COLOR_HIST_BINS * 3  # 3 channels
LBP_FEATURE_SIZE = LBP_POINTS + 2
HOG_FEATURE_SIZE = ((64 // HOG_PIXELS_PER_CELL[0] - HOG_CELLS_PER_BLOCK[0] + 1) *
                    (64 // HOG_PIXELS_PER_CELL[1] - HOG_CELLS_PER_BLOCK[1] + 1) *
                    HOG_CELLS_PER_BLOCK[0] * HOG_CELLS_PER_BLOCK[1] * HOG_ORIENTATIONS)
TOTAL_FEATURE_SIZE = COLOR_FEATURE_SIZE + LBP_FEATURE_SIZE + HOG_FEATURE_SIZE

# %% [markdown]
# #### This cell defines a series of functions for image processing and feature extraction, including reading images from a folder, computing color histograms, texture, and edge features, resizing images, and computing feature vectors. It also includes functions to interact with Qdrant for storing and querying image embeddings.

# %%
def store_single_embedding_in_qdrant(client, collection_name, image_path, feature_vector):
    """
    Stores a single embedding in Qdrant collection.

    Args:
        client (QdrantClient): The Qdrant client object.
        collection_name (str): The name of the collection to store the embedding in.
        image_path (str): The path of the image.
        feature_vector (numpy.ndarray): The feature vector of the image.

    Returns:
        None
    """
    # Create a payload with the image path
    payload = {"image_path": image_path}
    # Generate a unique ID for the point
    point_id = str(uuidpy.uuid4())
    # Create the point structure
    point = models.PointStruct(id=point_id, vector=feature_vector.tolist(), payload=payload)
    # Insert the point into the collection
    client.upsert(collection_name=collection_name, points=[point], wait=True)

def compute_color_histogram(image, bins=COLOR_HIST_BINS):
    """
    Compute the color histogram of an image.

    Parameters:
    image (numpy.ndarray): The input image.
    bins (int): The number of bins for the histogram. Default is COLOR_HIST_BINS.

    Returns:
    numpy.ndarray: The computed color histogram.

    """
    hist = [cv2.calcHist([image], [i], None, [bins], [0, 256]) for i in range(3)]
    hist = np.concatenate(hist).flatten()
    hist = hist / hist.sum()
    return hist

def compute_texture_features(image, radius=LBP_RADIUS, n_points=LBP_POINTS):
    """
    Compute texture features using Local Binary Patterns (LBP) on the given image.

    Parameters:
    - image: numpy.ndarray
        The input image.
    - radius: int, optional
        The radius of the circular neighborhood used for LBP. Default is LBP_RADIUS.
    - n_points: int, optional
        The number of points to sample on the circular neighborhood. Default is LBP_POINTS.

    Returns:
    - lbp_hist: numpy.ndarray
        The histogram of the Local Binary Patterns (LBP) computed on the image.
    """
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray_image, n_points, radius, method='uniform')
    lbp_hist, _ = np.histogram(lbp, bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
    lbp_hist = lbp_hist / lbp_hist.sum()
    return lbp_hist

def compute_edge_features(image):
    """
    Compute edge features of an image.

    Parameters:
    image (numpy.ndarray): The input image.

    Returns:
    numpy.ndarray: The computed edge histogram.

    """
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    sobelx = cv2.Sobel(gray_image, cv2.CV_64F, 1, 0, ksize=5)
    sobely = cv2.Sobel(gray_image, cv2.CV_64F, 0, 1, ksize=5)
    edges = np.sqrt(sobelx ** 2 + sobely ** 2)
    edge_hist, _ = np.histogram(edges, bins=32, range=(0, 256))
    edge_hist = edge_hist / edge_hist.sum()
    return edge_hist

def resize_image(image, target_size=(128, 128)):
    """
    Resize the input image to the specified target size.
    
    Parameters:
    image (numpy.ndarray): The input image to be resized.
    target_size (tuple): The target size to resize the image to. Default is (128, 128).
    
    Returns:
    numpy.ndarray: The resized image.
    """
    resized_image = cv2.resize(image, target_size)
    return resized_image

def compute_feature_vector(image_path):
    """
    Compute the feature vector for an image.

    Parameters:
    image_path (str): The path to the image file.

    Returns:
    numpy.ndarray: The computed feature vector.
    """

    image = cv2.imread(image_path)
    print("image>>", image.shape)
    color_features = compute_color_histogram(image)
    texture_features = compute_texture_features(image)
    edge_features = compute_edge_features(image)
    weighted_color_features = color_features * 2
    feature_vector = np.concatenate([weighted_color_features, texture_features, edge_features])
    print("FV>>", len(feature_vector))

    return feature_vector


def create_qdrant_collection(client, collection_name, vector_dim):
    """
    Create a new collection in Qdrant.

    Args:
        client (QdrantClient): The Qdrant client object.
        collection_name (str): The name of the collection to be created.
        vector_dim (int): The dimension of the vectors in the collection.

    Returns:
        None
    """
    # Create a new collection if it does not exist
    client.create_collection(
        collection_name=collection_name,
        vectors_config=models.VectorParams(size=vector_dim, distance=models.Distance.COSINE),
    )


def find_similar_images_in_qdrant(client, collection_name, input_image, top_k=2):
    """
    Find similar images in Qdrant collection based on an input image.

    Parameters:
    - client: Qdrant client object.
    - collection_name: Name of the collection in Qdrant.
    - input_image: Input image for which similar images need to be found.
    - top_k: Number of similar images to retrieve (default is 2).

    Returns:
    - List of dictionaries containing the URL and filename of similar images.
    """

    input_features = compute_feature_vector(input_image)

    # input_reduced_features = input_features
    search_result = client.search(
        collection_name=collection_name,
        query_vector=input_features.tolist(),
        query_filter=None,
        limit=top_k,
    )
    print("SR>>",search_result)
    similar_images = []
    for hit in search_result:
        print("hit>>",hit)
        similar_images.append({"url":hit.payload["url"], "filename":"/home/arunchandra/Downloads/images/"+hit.payload["filename"]})
    return similar_images



def process_image(image_path):
    """
    Wrapper function for processing a single image.
    
    Args:
        image_path (str): The path to the image file.
    
    Returns:
        tuple: A tuple containing the image_path and its feature_vector.
    """
    feature_vector = compute_feature_vector(image_path)
    return (image_path, feature_vector)

def process_and_store_images_parallel(folder_path, client, collection_name, vector_dim, max_workers=None):
    """
    Process and store images in parallel.

    Args:
        folder_path (str): The path to the folder containing the images.
        client: The client object for interacting with the Qdrant collection.
        collection_name (str): The name of the Qdrant collection.
        vector_dim (int): The dimension of the feature vectors.
        max_workers (int, optional): The maximum number of worker processes to use for parallel processing.
            If not specified, the default number of workers will be used.

    Returns:
        None
    """
    
    # Ensure the collection exists or create it if not
    create_qdrant_collection(client, collection_name, vector_dim)
    
    # Read image paths from the folder
    image_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith(('.jpg', '.jpeg', '.png'))]
    
    # Process images in parallel to compute feature vectors
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        for image_path, feature_vector in executor.map(process_image, image_paths):
            store_single_embedding_in_qdrant(client, collection_name, image_path, feature_vector)

# %% [markdown]
# #### The main execution cell initializes the Qdrant client, specifies the folder path containing images, and processes these images in parallel to compute and store their feature vectors in a Qdrant collection. The vector dimension is set, and the collection name is defined.

# %%
# Main code
folder_path = '/home/arunchandra/Downloads/final'
client = QdrantClient(url="http://localhost:6333",api_key="API_KEY")
collection_name = "image_collection_final_color_edge"
process_and_store_images_parallel(folder_path, client, collection_name, 154)
# Out:
# image>> image>> (1440, 1080, 3)
# image>> (1440, 1080, 3)
# (1440, 1080, 3)image>> image>>
# image>>(2400, 1800, 3)image>> (2400, 1800, 3) (1440, 1080, 3)
#
# image>>
# (2400, 1800, 3)(2400, 1800, 3)
#
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (480, 360, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> image>>(2400, 1800, 3)
#  (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>> (2400, 1800, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>>  FV>>(1440, 1080, 3)154
# 154
#
# image>> (1440, 1080, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>FV>>
#  154
# 154
# image>> (1440, 1080, 3)
# image>> image>>(2400, 1800, 3)FV>>
# (2400, 1800, 3)
#  154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)FV>> 154
#
# image>> FV>>(1440, 1080, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>>image>> (1440, 1080, 3)
#  (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>> 154
#  (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)FV>>
#  154FV>>
#  154
# image>> image>> (2400, 1800, 3)
# (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
#  (1440, 1080, 3)image>> (1440, 1080, 3)
#
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> image>>154
# (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154FV>>
# 154image>>
#  (1440, 1080, 3)
# FV>> 154image>> (1440, 1080, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (480, 360, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
# (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (480, 360, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>> 154
#  (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)image>>
# (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> FV>>(1440, 1080, 3)
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154 (2400, 1800, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>>FV>> 154 (2400, 1800, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>>FV>> (1440, 1080, 3) 154
#
# FV>> image>> (2400, 1800, 3)
# 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>>  154
# (480, 360, 3)image>>
# (1440, 1080, 3)
# FV>> 154
# image>> FV>>(2400, 1800, 3)
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>>  (2400, 1800, 3)
# 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> image>> (1440, 1080, 3)
# (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>>FV>>  154
# 154
# image>> (1440, 1080, 3)image>>
#  (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>> (2400, 1800, 3)
#  154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2401, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>>FV>>  (1440, 1080, 3)154
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>>FV>>  154154
#
# image>> image>> (1440, 1080, 3)
# (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>>154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# image>> (1440, 1080, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>>FV>> 154
# 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)image>>
# (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)FV>>
#  154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (480, 360, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>>image>>  (1440, 1080, 3)
# (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> image>> (1440, 1080, 3)154
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>>FV>>  154154
#
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>>FV>> 154 154
#
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> image>> (2400, 1800, 3)(2400, 1800, 3)
#
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> image>>(2400, 1800, 3) FV>>(2400, 1800, 3)
#
#  154
# FV>> 154
# image>> (2400, 1800, 3)FV>>
#  154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>>FV>> 154 154
#
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>> 154
#  (2400, 1800, 3)
# FV>> image>>154
#  (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# image>>image>> (1440, 1080, 3)
#  (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)FV>>
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)FV>>
# 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)FV>> 154
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154image>> (2400, 1800, 3)
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>> (2400, 1800, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)FV>> 154
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>>  (2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> FV>>(2400, 1800, 3)
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>> (2400, 1800, 3)
#  154
# image>>FV>>  (1440, 1080, 3)154
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>>
#  (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)FV>>
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>>image>>  (1440, 1080, 3)
# 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>>  154
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)image>>
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> FV>>154
#  154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> image>> 154(2400, 1800, 3)
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>>FV>>  (2400, 1800, 3)154
#
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (480, 360, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1600, 1200, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> FV>>(2400, 1800, 3) 154
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>>  (1440, 1080, 3)
# 154
# FV>>image>> (1440, 1080, 3)
#  154
# image>> (200, 150, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (720, 540, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>>FV>>  154154
#
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>> 154
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>> 154
# (1440, 1080, 3)
# FV>> 154image>>
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> image>>(2400, 1800, 3)
#  (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)image>>
# (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (480, 360, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)image>> (1440, 1080, 3)
#
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)FV>>
# 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>>FV>>  (2400, 1800, 3)154
#
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)image>> (2400, 1800, 3)
#
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>>FV>>  (2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>>FV>> 154
#  154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154image>>
#  (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)image>>
#  (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>>FV>> 154
#  154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>> (2400, 1800, 3)154
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> FV>>154 154
#
# image>>image>> (1440, 1080, 3)
# (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (200, 150, 3)FV>>
#  154
# FV>> 154
# image>>image>>  (1440, 1080, 3)(2400, 1800, 3)
#
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
# 154
# image>> image>>(2400, 1800, 3)image>>
# (1440, 1080, 3)
# (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>>FV>> 154
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (480, 360, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# image>> (2400, 1800, 3)
# image>> (2700, 2700, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>>FV>> (2400, 1800, 3)
# 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>>  154
# (1440, 1080, 3)image>>
# (480, 360, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)image>> (2400, 1800, 3)
#
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>>FV>> 154
#  154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> FV>> 154
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)FV>>
#  154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>> 154
# (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>>  (480, 360, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>>
# (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>>FV>>  154154
#
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> FV>> 154(2400, 1800, 3)
#
# FV>> 154
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# FV>> 154
# image>> image>> (2400, 1800, 3)
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
#  (200, 150, 3)
# image>> FV>>(1440, 1080, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)FV>>
#  154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>> (2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> image>>(2400, 1800, 3)
# (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>>  154
# (1440, 1080, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> image>>154
#  (1440, 1080, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154image>>
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)FV>> 154
#
# image>> (1440, 1080, 3)
# FV>> FV>>154 154
#
# image>> image>>(2400, 1800, 3) (2400, 1800, 3)
#
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)FV>>
# 154
# image>> FV>> (1440, 1080, 3)154
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# FV>>image>> 154
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>>  (1440, 1080, 3)154
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>>FV>>  (2400, 1800, 3)
# 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>>image>> 154
#  (1440, 1080, 3)image>>
#  (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154 (2400, 1800, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>>FV>>  154
# (2400, 1800, 3)
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>>image>> (2400, 1800, 3)
# 154FV>>
#  154
# image>>image>> (1440, 1080, 3) (2400, 1800, 3)
#
# FV>> 154
# image>> (1440, 1080, 3)FV>>
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154image>> (1440, 1080, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)FV>>
#  154
# image>> (480, 360, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
# 154
# image>>image>>  (1440, 1080, 3)(1440, 1080, 3)
#
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>>FV>>  154154
#
# image>> (2400, 1800, 3)image>> (2400, 1800, 3)
#
# FV>> 154
# FV>>image>>  (2400, 1800, 3)154
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# image>> (480, 360, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>>image>>  (1440, 1080, 3)(2400, 1800, 3)
#
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>>  (1440, 1080, 3)154
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>>image>> (2400, 1800, 3)
# (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>>FV>> 154
#  154
# image>>image>> (2400, 1800, 3)
# (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)image>>
#  (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (480, 360, 3)
# FV>> 154
# FV>>image>>  (1440, 1080, 3)154FV>>
#
#  FV>>154
#  154
# image>>image>> (2400, 1800, 3)
#  (2400, 1800, 3)
# image>>FV>>  154(2400, 1800, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> FV>>154
# image>> (200, 150, 3)154
#
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>>FV>> 154 154
#
# image>> (1440, 1080, 3)FV>>
# image>> 154
#  (2400, 1800, 3)FV>>
#  154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> FV>> 154
# 154
# image>> (2400, 1800, 3)image>>
# image>> (2400, 1800, 3)
# (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> FV>>(1440, 1080, 3)
#  154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>>image>> FV>> (2400, 1800, 3)(1440, 1080, 3)
#
# 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>>FV>> (2400, 1800, 3) 154
#
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> FV>>154
#  154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>>  154(2400, 1800, 3)
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)image>>
#  (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>>FV>>  154
# 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154FV>>
#  image>>154
#  (2400, 1800, 3)
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>>FV>>  154154
#
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)image>>
# (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>> (2400, 1800, 3)
#  154
# image>> (1440, 1080, 3)FV>>
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (480, 360, 3)
# FV>> 154FV>>
#  154
# image>> (2400, 1800, 3)image>>
#  (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>> (2400, 1800, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>>FV>>  154154
#
# FV>>image>>  image>>(1440, 1080, 3)
# 154
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>> 154 (2400, 1800, 3)
#
# image>> (2400, 1800, 3)FV>>
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)FV>>
# 154image>>
# (2400, 1800, 3)FV>>
#  154
# image>> image>>(1440, 1080, 3)
# (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
# 154
# image>> (1440, 1080, 3)FV>>
#  image>>154
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)FV>>
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>> (2400, 1800, 3)
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> FV>>(2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>>image>>  (1440, 1080, 3)(2400, 1800, 3)
#
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>>FV>> 154 154
#
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154FV>>
#  154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>> 154
# image>> (200, 150, 3)
#
# FV>>image>> 154
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>>FV>> 154 (1440, 1080, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154FV>>
# image>>  154
# (480, 360, 3)
# image>> image>>(2400, 1800, 3)
#  (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>>FV>> (2400, 1800, 3)
#  154image>>
# (2400, 1800, 3)
# image>> (1440, 1080, 3)FV>>
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> FV>> 154154
#
# image>> (2400, 1800, 3)
# FV>> FV>>154
# 154image>> (200, 150, 3)image>>
#
#  (2400, 1800, 3)FV>>
#  154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> FV>>(1440, 1080, 3)FV>>  154
# 154
#
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>>image>> (2400, 1800, 3) (1440, 1080, 3)
#
# FV>> 154
# FV>> 154
# image>>image>>  (2400, 1800, 3)
# (200, 150, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# FV>>image>>  (2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)image>> (2400, 1800, 3)
#
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# image>> (2400, 1800, 3)image>>
# (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)FV>>
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (720, 540, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>> (2400, 1800, 3)
#  154
# FV>> 154image>>
# FV>>  154(2400, 1800, 3)
#
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>> (1440, 1080, 3)
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> FV>>(2400, 1800, 3)
#  154
# image>> (200, 150, 3)
# FV>>FV>> 154
#  154
# image>> (2400, 1800, 3)
# image>>FV>>  (2400, 1800, 3)154
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>>image>>  (1440, 1080, 3)(1440, 1080, 3)
#
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> FV>> 154154
#
# image>> (200, 150, 3)
# image>> FV>>(2400, 1800, 3)
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
#  (1440, 1080, 3)
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>>FV>>  154(1440, 1080, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# ...
# FV>> 154FV>>
# 154
# image>>FV>> (1440, 1080, 3) image>>154
# (2400, 1800, 3)
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>>
#  (2400, 1800, 3)image>>
#  (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> FV>>154 154
#
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>>FV>> (2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> FV>> 154154
#
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> FV>>(2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> FV>>154
# image>>154
#  (200, 150, 3)
# image>>FV>>  (2400, 1800, 3)154
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> FV>>154
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>>image>>  (200, 150, 3)
# (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
#  (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>FV>>  154154
#
# image>> image>>(2400, 1800, 3) image>>(1440, 1080, 3)
#
#  (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> FV>>154
#  image>>154
#  (1440, 1080, 3)
# image>>FV>> (2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> image>>(2400, 1800, 3)
# (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>>FV>> (1440, 1080, 3)
#  image>>154 (2400, 1800, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> FV>>154
#  154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>>  154(1440, 1080, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>>154
# (2400, 1800, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)image>>
#  (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>> 154(2400, 1800, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>>image>> (2400, 1800, 3)
# (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>>  154
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154FV>>
#  154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> FV>>154
# 154
# image>> image>>(1440, 1080, 3)
#  (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154FV>>
# image>>  (2400, 1800, 3)154
#
# image>> FV>>(2400, 1800, 3)
#  154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>>
# (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> FV>> 154154
#
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>>  154
# (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> FV>> 154154
#
# image>> image>> (2400, 1800, 3)
# (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> image>> (1440, 1080, 3)
# (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>>FV>>  154
# 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>>
#  image>> (1440, 1080, 3)(1440, 1080, 3)
#
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>> (2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> FV>>(1440, 1080, 3) 154
#
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)image>>
#  (2400, 1800, 3)
# FV>> 154
# FV>> image>> (2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)FV>>
#  154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> FV>>(1440, 1080, 3)
# 154
# image>> (1440, 1080, 3)
# FV>>FV>>  154154
#
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>>image>>  (2400, 1800, 3)
# 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> FV>> 154
# 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>>image>>  (720, 540, 3)
# (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154image>> (1440, 1080, 3)
#
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)FV>>
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154FV>>
#  154
# image>> (2400, 1800, 3)
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# FV>> 154image>>
# image>> (2400, 1800, 3)
#  (1440, 1080, 3)
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> image>> 154(2400, 1800, 3)
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> image>>(2400, 1800, 3)
#  (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> FV>>(2400, 1800, 3) 154
#
# image>> (2400, 1800, 3)FV>> 154
#
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> image>> (2400, 1800, 3)
# (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)image>>
#  (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>>FV>> (2400, 1800, 3)
#  154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154image>>
#  (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> FV>>(2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154FV>>
#  154
# image>> FV>>(1440, 1080, 3)
# image>>  154(2400, 1800, 3)
#
# image>> (200, 150, 3)
# FV>> 154
# FV>>image>>  (2400, 1800, 3)
# 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (720, 540, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> image>>(2400, 1800, 3)
#  (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (200, 150, 3)
# FV>> 154
# FV>> image>> (2400, 1800, 3)154
#
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>>image>> (2400, 1800, 3)
# (200, 150, 3)
# FV>>FV>>  154154
#
# FV>> 154
# image>> (1440, 1080, 3)
# image>>image>>  (2400, 1800, 3)(2400, 1800, 3)
#
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# image>> (1440, 1080, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# FV>> 154
# image>> (2400, 1800, 3)
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (1440, 1080, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# image>> (2400, 1800, 3)
# FV>> 154
# FV>> 154
# FV>> 154
# FV>> 154
# FV>> 154
# FV>> 154
# FV>> 154
# FV>> 154

# %% [markdown]
# #### This cell uses the Qdrant client to find similar images to a given input image by querying the Qdrant collection. The top k similar images are retrieved and displayed.
#
# > Note: In this approach each feature has equal weights

# %%
input_image = '/home/arunchandra/Downloads/6.jpeg'
client = QdrantClient(url="http://localhost:6333",api_key="API_KEY")
collection_name = "jtp_final"
# Find similar images using Qdrant
similar_images = find_similar_images_in_qdrant(client, collection_name, input_image, top_k=20)
similar_images.append({"filename":input_image})
print("Similar images:", similar_images)
# Out:
# image>> (213, 237, 3)
# FV>> 154
# SR>> [ScoredPoint(id='0f6497b5-bad8-4481-90d5-ce52e791029e', version=17899, score=0.98652333, payload={'filename': '37494.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/eceffbcf057cbebd699c2bdc9cead8d8_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='aff3bc51-3751-4fd7-8511-7bb974b20c11', version=37708, score=0.98641115, payload={'filename': '59219.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Titan-Him---Her-White-Watches_694d813fee5372d1b9a8d7041f8728de_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='a402c733-6c50-4045-ae0e-2380204cd362', version=34412, score=0.9861952, payload={'filename': '14733.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/630e7346de21c619979a5e7010b53c2d_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='3c706324-7d8e-4658-b00b-2a74aadad703', version=39144, score=0.9850165, payload={'filename': '56667.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Maxima-Men-White-Dial-Watch_eafdba778651344e8fca49e1746e2737_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='331bec52-9fa3-474c-8956-36f63ac6f708', version=18211, score=0.98497194, payload={'filename': '36942.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/636a9734a2651b97ba61a59c3ec1a2b7_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='7d4311a6-bd82-4fb6-bf1c-00fea1bb1d66', version=17125, score=0.9844661, payload={'filename': '59240.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Titan-Men-White-Dial-Watch_03facedf256cd301b4d92254b7547dd2_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='5e3d5f4b-8db9-4cf1-bf8f-bea5f8af6dc5', version=41061, score=0.98441184, payload={'filename': '33250.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/ed61f5eea0ca2f92f1ab9c526360c6b1_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='c7f2f6c3-a806-47ee-91f6-ad5816718a5f', version=40498, score=0.98377556, payload={'filename': '36941.jpg', 'url': 'http://assets.myntassets.com/assets/images/36941/2016/5/20/11463745839222-Fossil-Men-Quartz-White-Dial-Chronograph-Watch-CH2696-1711463745839105-1.jpg'}, vector=None, shard_key=None), ScoredPoint(id='d5b1245d-e184-4fa0-b8f5-6be288a356d0', version=22471, score=0.9835307, payload={'filename': '32336.jpg', 'url': 'http://assets.myntassets.com/v1/image/style/properties/32336/QQ-Dynamiq-Men-White-Dial-Watch-Q276J404Y_1_e246fae23707eab3b7f5e8c22a538373.jpg'}, vector=None, shard_key=None), ScoredPoint(id='d06fe613-68db-49f1-8f4d-c14ec589c7b4', version=22901, score=0.9834398, payload={'filename': '43151.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/8c33b043ffdb9d6d796e160d738832ae_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='81a25d8e-ca1e-4773-83ce-f14ef676e198', version=38358, score=0.9830238, payload={'filename': '33869.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Citizen-Men-Steel-Chronograph-Watch_7742c46710608d4fe32d6ddef0a38c52_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='921f6559-dce7-4c78-a453-8bdb1072da6d', version=21566, score=0.98300815, payload={'filename': '38031.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/8cccc2d28320d1d7432991c4dccfb150_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='ea0a9b10-71a1-4977-9e72-025f28ce7b6a', version=11020, score=0.98296607, payload={'filename': '29411.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/e38884ad25e24546fb027208ffb17248_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='a279022e-38bd-410c-b6cb-945df20ddc98', version=6659, score=0.9828976, payload={'filename': '19296.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Guess-Women-Icon-Squared-White-Watch8916565a45e2d154603091cfe7dae6ae_images.jpg'}, vector=None, shard_key=None), ScoredPoint(id='55822819-83a6-46e7-a43f-884f7200543c', version=3901, s ...
# hit>> id='0f6497b5-bad8-4481-90d5-ce52e791029e' version=17899 score=0.98652333 payload={'filename': '37494.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/eceffbcf057cbebd699c2bdc9cead8d8_images.jpg'} vector=None shard_key=None
# hit>> id='aff3bc51-3751-4fd7-8511-7bb974b20c11' version=37708 score=0.98641115 payload={'filename': '59219.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Titan-Him---Her-White-Watches_694d813fee5372d1b9a8d7041f8728de_images.jpg'} vector=None shard_key=None
# hit>> id='a402c733-6c50-4045-ae0e-2380204cd362' version=34412 score=0.9861952 payload={'filename': '14733.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/630e7346de21c619979a5e7010b53c2d_images.jpg'} vector=None shard_key=None
# hit>> id='3c706324-7d8e-4658-b00b-2a74aadad703' version=39144 score=0.9850165 payload={'filename': '56667.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Maxima-Men-White-Dial-Watch_eafdba778651344e8fca49e1746e2737_images.jpg'} vector=None shard_key=None
# hit>> id='331bec52-9fa3-474c-8956-36f63ac6f708' version=18211 score=0.98497194 payload={'filename': '36942.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/636a9734a2651b97ba61a59c3ec1a2b7_images.jpg'} vector=None shard_key=None
# hit>> id='7d4311a6-bd82-4fb6-bf1c-00fea1bb1d66' version=17125 score=0.9844661 payload={'filename': '59240.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Titan-Men-White-Dial-Watch_03facedf256cd301b4d92254b7547dd2_images.jpg'} vector=None shard_key=None
# hit>> id='5e3d5f4b-8db9-4cf1-bf8f-bea5f8af6dc5' version=41061 score=0.98441184 payload={'filename': '33250.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/ed61f5eea0ca2f92f1ab9c526360c6b1_images.jpg'} vector=None shard_key=None
# hit>> id='c7f2f6c3-a806-47ee-91f6-ad5816718a5f' version=40498 score=0.98377556 payload={'filename': '36941.jpg', 'url': 'http://assets.myntassets.com/assets/images/36941/2016/5/20/11463745839222-Fossil-Men-Quartz-White-Dial-Chronograph-Watch-CH2696-1711463745839105-1.jpg'} vector=None shard_key=None
# hit>> id='d5b1245d-e184-4fa0-b8f5-6be288a356d0' version=22471 score=0.9835307 payload={'filename': '32336.jpg', 'url': 'http://assets.myntassets.com/v1/image/style/properties/32336/QQ-Dynamiq-Men-White-Dial-Watch-Q276J404Y_1_e246fae23707eab3b7f5e8c22a538373.jpg'} vector=None shard_key=None
# hit>> id='d06fe613-68db-49f1-8f4d-c14ec589c7b4' version=22901 score=0.9834398 payload={'filename': '43151.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/8c33b043ffdb9d6d796e160d738832ae_images.jpg'} vector=None shard_key=None
# hit>> id='81a25d8e-ca1e-4773-83ce-f14ef676e198' version=38358 score=0.9830238 payload={'filename': '33869.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Citizen-Men-Steel-Chronograph-Watch_7742c46710608d4fe32d6ddef0a38c52_images.jpg'} vector=None shard_key=None
# hit>> id='921f6559-dce7-4c78-a453-8bdb1072da6d' version=21566 score=0.98300815 payload={'filename': '38031.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/8cccc2d28320d1d7432991c4dccfb150_images.jpg'} vector=None shard_key=None
# hit>> id='ea0a9b10-71a1-4977-9e72-025f28ce7b6a' version=11020 score=0.98296607 payload={'filename': '29411.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/e38884ad25e24546fb027208ffb17248_images.jpg'} vector=None shard_key=None
# hit>> id='a279022e-38bd-410c-b6cb-945df20ddc98' version=6659 score=0.9828976 payload={'filename': '19296.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Guess-Women-Icon-Squared-White-Watch8916565a45e2d154603091cfe7dae6ae_images.jpg'} vector=None shard_key=None
# hit>> id='55822819-83a6-46e7-a43f-884f7200543c' version=3901 score=0.9828679 payload={'filename': '41030.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Nautica-Men-Silver-Dial-Watch_26e17342b3e3b60ab374d62e1602e2b2_images.jpg'} vector=None shard_key=None
# hit>> id='c496733c-77ca-4a32-8d72-fb8cc0e30ee7' version=39359 score=0.982683 payload={'filename': '44993.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/d2eb989316713e16109f00dd3c0ddbcc_images.jpg'} vector=None shard_key=None
# hit>> id='b1f395d7-01af-484d-bdfd-e5e8669845cf' version=35041 score=0.9825084 payload={'filename': '45935.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/2c3dcc4e8cca898d9a923d9e6b83d3ca_images.jpg'} vector=None shard_key=None
# hit>> id='7faf25d2-870b-4f48-9848-c81c796dc011' version=2953 score=0.9824606 payload={'filename': '29772.jpg', 'url': 'http://assets.myntassets.com/v1/image/style/properties/29772/Wrangler-Men-Red-Striped-Casual-Shirt_1_00e3e4684484663c408ea457e09b9856.jpg'} vector=None shard_key=None
# hit>> id='bbe80071-2a55-442e-b449-e0240e833f72' version=27498 score=0.98237544 payload={'filename': '56339.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/Fastrack-Women-Brown-Watch_2157a31df86ae9c68567df615b1af8bc_images.jpg'} vector=None shard_key=None
# hit>> id='eb3828c7-ba4c-4b30-92da-9d557189fcd5' version=36752 score=0.982262 payload={'filename': '23267.jpg', 'url': 'http://assets.myntassets.com/v1/images/style/properties/abea4f75f397e1b4df4a18fb3dd71c83_images.jpg'} vector=None shard_key=None
# Similar images: [{'url': 'http://assets.myntassets.com/v1/images/style/properties/eceffbcf057cbebd699c2bdc9cead8d8_images.jpg', 'filename': '/home/arunchandra/Downloads/images/37494.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/Titan-Him---Her-White-Watches_694d813fee5372d1b9a8d7041f8728de_images.jpg', 'filename': '/home/arunchandra/Downloads/images/59219.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/630e7346de21c619979a5e7010b53c2d_images.jpg', 'filename': '/home/arunchandra/Downloads/images/14733.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/Maxima-Men-White-Dial-Watch_eafdba778651344e8fca49e1746e2737_images.jpg', 'filename': '/home/arunchandra/Downloads/images/56667.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/636a9734a2651b97ba61a59c3ec1a2b7_images.jpg', 'filename': '/home/arunchandra/Downloads/images/36942.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/Titan-Men-White-Dial-Watch_03facedf256cd301b4d92254b7547dd2_images.jpg', 'filename': '/home/arunchandra/Downloads/images/59240.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/ed61f5eea0ca2f92f1ab9c526360c6b1_images.jpg', 'filename': '/home/arunchandra/Downloads/images/33250.jpg'}, {'url': 'http://assets.myntassets.com/assets/images/36941/2016/5/20/11463745839222-Fossil-Men-Quartz-White-Dial-Chronograph-Watch-CH2696-1711463745839105-1.jpg', 'filename': '/home/arunchandra/Downloads/images/36941.jpg'}, {'url': 'http://assets.myntassets.com/v1/image/style/properties/32336/QQ-Dynamiq-Men-White-Dial-Watch-Q276J404Y_1_e246fae23707eab3b7f5e8c22a538373.jpg', 'filename': '/home/arunchandra/Downloads/images/32336.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/8c33b043ffdb9d6d796e160d738832ae_images.jpg', 'filename': '/home/arunchandra/Downloads/images/43151.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/Citizen-Men-Steel-Chronograph-Watch_7742c46710608d4fe32d6ddef0a38c52_images.jpg', 'filename': '/home/arunchandra/Downloads/images/33869.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/8cccc2d28320d1d7432991c4dccfb150_images.jpg', 'filename': '/home/arunchandra/Downloads/images/38031.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/e38884ad25e24546fb027208ffb17248_images.jpg', 'filename': '/home/arunchandra/Downloads/images/29411.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/Guess-Women-Icon-Squared-White-Watch8916565a45e2d154603091cfe7dae6ae_images.jpg', 'filename': '/home/arunchandra/Downloads/images/19296.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/Nautica-Men-Silver-Dial-Watch_26e17342b3e3b60ab374d62e1602e2b2_images.jpg', 'filename': '/home/arunchandra/Downloads/images/41030.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/d2eb989316713e16109f00dd3c0ddbcc_images.jpg', 'filename': '/home/arunchandra/Downloads/images/44993.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/2c3dcc4e8cca898d9a923d9e6b83d3ca_images.jpg', 'filename': '/home/arunchandra/Downloads/images/45935.jpg'}, {'url': 'http://assets.myntassets.com/v1/image/style/properties/29772/Wrangler-Men-Red-Striped-Casual-Shirt_1_00e3e4684484663c408ea457e09b9856.jpg', 'filename': '/home/arunchandra/Downloads/images/29772.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/Fastrack-Women-Brown-Watch_2157a31df86ae9c68567df615b1af8bc_images.jpg', 'filename': '/home/arunchandra/Downloads/images/56339.jpg'}, {'url': 'http://assets.myntassets.com/v1/images/style/properties/abea4f75f397e1b4df4a18fb3dd71c83_images.jpg', 'filename': '/home/arunchandra/Downloads/images/23267.jpg'}, {'filename': '/home/arunchandra/Downloads/6.jpeg'}]

# %% [markdown]
# #### Displaying Images Using Matplotlib
#
# - The last image is the input image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# List of image file paths
image_paths = similar_images

# Define the dimensions of the image matrix
rows = 5
cols = 5

# Create a figure to display the images
fig, axes = plt.subplots(rows, cols, figsize=(10, 5))

# Iterate over the image paths and plot them in the matrix
for i in range(rows):
    for j in range(cols):
        ax = axes[j] if rows == 1 else axes[i, j]
        img_idx = i * cols + j
        if img_idx < len(image_paths):
            print("img_idx>>",image_paths[img_idx]['filename'])
            img = mpimg.imread(image_paths[img_idx]['filename'])
            ax.imshow(img)
        ax.axis('off')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# img_idx>> /home/arunchandra/Downloads/images/37494.jpg
# img_idx>> /home/arunchandra/Downloads/images/59219.jpg
# img_idx>> /home/arunchandra/Downloads/images/14733.jpg
# img_idx>> /home/arunchandra/Downloads/images/56667.jpg
# img_idx>> /home/arunchandra/Downloads/images/36942.jpg
# img_idx>> /home/arunchandra/Downloads/images/59240.jpg
# img_idx>> /home/arunchandra/Downloads/images/33250.jpg
# img_idx>> /home/arunchandra/Downloads/images/36941.jpg
# img_idx>> /home/arunchandra/Downloads/images/32336.jpg
# img_idx>> /home/arunchandra/Downloads/images/43151.jpg
# img_idx>> /home/arunchandra/Downloads/images/33869.jpg
# img_idx>> /home/arunchandra/Downloads/images/38031.jpg
# img_idx>> /home/arunchandra/Downloads/images/29411.jpg
# img_idx>> /home/arunchandra/Downloads/images/19296.jpg
# img_idx>> /home/arunchandra/Downloads/images/41030.jpg
# img_idx>> /home/arunchandra/Downloads/images/44993.jpg
# img_idx>> /home/arunchandra/Downloads/images/45935.jpg
# img_idx>> /home/arunchandra/Downloads/images/29772.jpg
# img_idx>> /home/arunchandra/Downloads/images/56339.jpg
# img_idx>> /home/arunchandra/Downloads/images/23267.jpg
# img_idx>> /home/arunchandra/Downloads/6.jpeg

# %% [markdown]
# #### This cell uses the Qdrant client to find similar images to a given input image by querying the Qdrant collection. The top k similar images are retrieved and displayed.
#
# > Note: In this approach the color feature is weighted.
#  Ratio is color:texture:edge = 2:1:1

# %%
input_image = '/media/arunchandra/local/Downloads/123.jpg'
client = QdrantClient(url="http://localhost:6333",api_key="API_KEY")
collection_name = "test_final_jtp_color_weighted"
# Find similar images using Qdrant
similar_images = find_similar_images_in_qdrant(client, collection_name, input_image, top_k=20)
similar_images.append(input_image)
print("Similar images:", similar_images)
# Out:
# image>> (2400, 1800, 3)
# FV>> 154
# SR>> [ScoredPoint(id='b29f1e5a-6e85-4b33-b2aa-b50151648731', version=0, score=0.98685586, payload={'image_path': '/home/arunchandra/Downloads/final/2103.jpg'}, vector=None, shard_key=None), ScoredPoint(id='a765d9aa-a0c4-44e2-9e7b-a3b50363c8e1', version=0, score=0.9808576, payload={'image_path': '/home/arunchandra/Downloads/final/2757.jpg'}, vector=None, shard_key=None), ScoredPoint(id='9d957b25-69b2-4b28-824c-4969e32cc382', version=0, score=0.9779484, payload={'image_path': '/home/arunchandra/Downloads/final/2760.jpg'}, vector=None, shard_key=None), ScoredPoint(id='dad2827d-3905-4a66-82f4-1187b6a421cc', version=0, score=0.97745794, payload={'image_path': '/home/arunchandra/Downloads/final/7176.jpg'}, vector=None, shard_key=None), ScoredPoint(id='7d59787d-4547-4e54-9189-4f41ab329c0a', version=0, score=0.97745067, payload={'image_path': '/home/arunchandra/Downloads/final/2099.jpg'}, vector=None, shard_key=None), ScoredPoint(id='85339950-b83c-42b3-b500-ea2ef7cb177d', version=0, score=0.97738874, payload={'image_path': '/home/arunchandra/Downloads/final/1801.jpg'}, vector=None, shard_key=None), ScoredPoint(id='f75c6c37-7787-4a80-b76b-14ff9a2e49a7', version=0, score=0.9764719, payload={'image_path': '/home/arunchandra/Downloads/final/2102.jpg'}, vector=None, shard_key=None), ScoredPoint(id='8e2fbb6e-47b8-4e14-8622-026e625001b3', version=0, score=0.9763151, payload={'image_path': '/home/arunchandra/Downloads/final/7169.jpg'}, vector=None, shard_key=None), ScoredPoint(id='6f798692-51de-4401-a2f8-6fd20a8fd312', version=0, score=0.9758787, payload={'image_path': '/home/arunchandra/Downloads/final/7051.jpg'}, vector=None, shard_key=None), ScoredPoint(id='7e9886b6-728c-4b69-8d13-4dc12055ce55', version=0, score=0.97562647, payload={'image_path': '/home/arunchandra/Downloads/final/6011.jpg'}, vector=None, shard_key=None), ScoredPoint(id='33b98963-f68c-4f07-883f-308f1b36abf7', version=0, score=0.97537005, payload={'image_path': '/home/arunchandra/Downloads/final/2095.jpg'}, vector=None, shard_key=None), ScoredPoint(id='116e7db3-316c-4961-9048-e65e8ae83fb2', version=0, score=0.97458977, payload={'image_path': '/home/arunchandra/Downloads/final/7170.jpg'}, vector=None, shard_key=None), ScoredPoint(id='e059c25b-e3b3-41b5-bf39-d27aec3c4ddc', version=0, score=0.97438234, payload={'image_path': '/home/arunchandra/Downloads/final/7175.jpg'}, vector=None, shard_key=None), ScoredPoint(id='7b7f7dec-c469-4e34-816d-7c0719f40ecb', version=0, score=0.97435576, payload={'image_path': '/home/arunchandra/Downloads/final/7149.jpg'}, vector=None, shard_key=None), ScoredPoint(id='a155a57f-7c11-441c-94dc-6ff7cf479adc', version=0, score=0.9742721, payload={'image_path': '/home/arunchandra/Downloads/final/2748.jpg'}, vector=None, shard_key=None), ScoredPoint(id='b4a771df-c427-4e06-a84c-f9c3151c73d5', version=0, score=0.973572, payload={'image_path': '/home/arunchandra/Downloads/final/4702.jpg'}, vector=None, shard_key=None), ScoredPoint(id='b24bb470-b50b-472e-9897-7ef74955f25f', version=0, score=0.9734812, payload={'image_path': '/home/arunchandra/Downloads/final/5741.jpg'}, vector=None, shard_key=None), ScoredPoint(id='555acb7d-d93b-4e95-a64d-38777fe6b83f', version=0, score=0.97331905, payload={'image_path': '/home/arunchandra/Downloads/final/4371.jpg'}, vector=None, shard_key=None), ScoredPoint(id='18088c22-b112-453c-9b88-fe42f23fda39', version=0, score=0.9730047, payload={'image_path': '/home/arunchandra/Downloads/final/7172.jpg'}, vector=None, shard_key=None), ScoredPoint(id='3c1df110-d8a2-4c1b-8e1a-20b329fd8178', version=0, score=0.9725246, payload={'image_path': '/home/arunchandra/Downloads/final/2749.jpg'}, vector=None, shard_key=None)]
# hit>> id='b29f1e5a-6e85-4b33-b2aa-b50151648731' version=0 score=0.98685586 payload={'image_path': '/home/arunchandra/Downloads/final/2103.jpg'} vector=None shard_key=None
# hit>> id='a765d9aa-a0c4-44e2-9e7b-a3b50363c8e1' version=0 score=0.9808576 payload={'image_path': '/home/arunchandra/Downloads/final/2757.jpg'} vector=None shard_key=None
# hit>> id='9d957b25-69b2-4b28-824c-4969e32cc382' version=0 score=0.9779484 payload={'image_path': '/home/arunchandra/Downloads/final/2760.jpg'} vector=None shard_key=None
# hit>> id='dad2827d-3905-4a66-82f4-1187b6a421cc' version=0 score=0.97745794 payload={'image_path': '/home/arunchandra/Downloads/final/7176.jpg'} vector=None shard_key=None
# hit>> id='7d59787d-4547-4e54-9189-4f41ab329c0a' version=0 score=0.97745067 payload={'image_path': '/home/arunchandra/Downloads/final/2099.jpg'} vector=None shard_key=None
# hit>> id='85339950-b83c-42b3-b500-ea2ef7cb177d' version=0 score=0.97738874 payload={'image_path': '/home/arunchandra/Downloads/final/1801.jpg'} vector=None shard_key=None
# hit>> id='f75c6c37-7787-4a80-b76b-14ff9a2e49a7' version=0 score=0.9764719 payload={'image_path': '/home/arunchandra/Downloads/final/2102.jpg'} vector=None shard_key=None
# hit>> id='8e2fbb6e-47b8-4e14-8622-026e625001b3' version=0 score=0.9763151 payload={'image_path': '/home/arunchandra/Downloads/final/7169.jpg'} vector=None shard_key=None
# hit>> id='6f798692-51de-4401-a2f8-6fd20a8fd312' version=0 score=0.9758787 payload={'image_path': '/home/arunchandra/Downloads/final/7051.jpg'} vector=None shard_key=None
# hit>> id='7e9886b6-728c-4b69-8d13-4dc12055ce55' version=0 score=0.97562647 payload={'image_path': '/home/arunchandra/Downloads/final/6011.jpg'} vector=None shard_key=None
# hit>> id='33b98963-f68c-4f07-883f-308f1b36abf7' version=0 score=0.97537005 payload={'image_path': '/home/arunchandra/Downloads/final/2095.jpg'} vector=None shard_key=None
# hit>> id='116e7db3-316c-4961-9048-e65e8ae83fb2' version=0 score=0.97458977 payload={'image_path': '/home/arunchandra/Downloads/final/7170.jpg'} vector=None shard_key=None
# hit>> id='e059c25b-e3b3-41b5-bf39-d27aec3c4ddc' version=0 score=0.97438234 payload={'image_path': '/home/arunchandra/Downloads/final/7175.jpg'} vector=None shard_key=None
# hit>> id='7b7f7dec-c469-4e34-816d-7c0719f40ecb' version=0 score=0.97435576 payload={'image_path': '/home/arunchandra/Downloads/final/7149.jpg'} vector=None shard_key=None
# hit>> id='a155a57f-7c11-441c-94dc-6ff7cf479adc' version=0 score=0.9742721 payload={'image_path': '/home/arunchandra/Downloads/final/2748.jpg'} vector=None shard_key=None
# hit>> id='b4a771df-c427-4e06-a84c-f9c3151c73d5' version=0 score=0.973572 payload={'image_path': '/home/arunchandra/Downloads/final/4702.jpg'} vector=None shard_key=None
# hit>> id='b24bb470-b50b-472e-9897-7ef74955f25f' version=0 score=0.9734812 payload={'image_path': '/home/arunchandra/Downloads/final/5741.jpg'} vector=None shard_key=None
# hit>> id='555acb7d-d93b-4e95-a64d-38777fe6b83f' version=0 score=0.97331905 payload={'image_path': '/home/arunchandra/Downloads/final/4371.jpg'} vector=None shard_key=None
# hit>> id='18088c22-b112-453c-9b88-fe42f23fda39' version=0 score=0.9730047 payload={'image_path': '/home/arunchandra/Downloads/final/7172.jpg'} vector=None shard_key=None
# hit>> id='3c1df110-d8a2-4c1b-8e1a-20b329fd8178' version=0 score=0.9725246 payload={'image_path': '/home/arunchandra/Downloads/final/2749.jpg'} vector=None shard_key=None
# Similar images: ['/home/arunchandra/Downloads/final/2103.jpg', '/home/arunchandra/Downloads/final/2757.jpg', '/home/arunchandra/Downloads/final/2760.jpg', '/home/arunchandra/Downloads/final/7176.jpg', '/home/arunchandra/Downloads/final/2099.jpg', '/home/arunchandra/Downloads/final/1801.jpg', '/home/arunchandra/Downloads/final/2102.jpg', '/home/arunchandra/Downloads/final/7169.jpg', '/home/arunchandra/Downloads/final/7051.jpg', '/home/arunchandra/Downloads/final/6011.jpg', '/home/arunchandra/Downloads/final/2095.jpg', '/home/arunchandra/Downloads/final/7170.jpg', '/home/arunchandra/Downloads/final/7175.jpg', '/home/arunchandra/Downloads/final/7149.jpg', '/home/arunchandra/Downloads/final/2748.jpg', '/home/arunchandra/Downloads/final/4702.jpg', '/home/arunchandra/Downloads/final/5741.jpg', '/home/arunchandra/Downloads/final/4371.jpg', '/home/arunchandra/Downloads/final/7172.jpg', '/home/arunchandra/Downloads/final/2749.jpg', '/media/arunchandra/local/Downloads/123.jpg']

# %% [markdown]
# #### Displaying Images Using Matplotlib
#
# - The last image is the input image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# List of image file paths
image_paths = similar_images

# Define the dimensions of the image matrix
rows = 5
cols = 5

# Create a figure to display the images
fig, axes = plt.subplots(rows, cols, figsize=(10, 5))

# Iterate over the image paths and plot them in the matrix
for i in range(rows):
    for j in range(cols):
        ax = axes[j] if rows == 1 else axes[i, j]
        img_idx = i * cols + j
        if img_idx < len(image_paths):
            img = mpimg.imread(image_paths[img_idx])
            ax.imshow(img)
        ax.axis('off')

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### This cell uses the Qdrant client to find similar images to a given input image by querying the Qdrant collection. The top k similar images are retrieved and displayed.
#
# > Note: In this approach the color and edge feature is weighted.
#  Ratio is color:texture:edge = 2:1:2

# %%
input_image = '/media/arunchandra/local/Downloads/123.jpg'
client = QdrantClient(url="http://localhost:6333",api_key="API_KEY")
collection_name = "image_collection_final"
# Find similar images using Qdrant
similar_images = find_similar_images_in_qdrant(client, collection_name, input_image, top_k=20)
similar_images.append(input_image)
print("Similar images:", similar_images)
# Out:
# image>> (2400, 1800, 3)
# FV>> 154
# SR>> [ScoredPoint(id='a24ec001-7029-48f5-b431-237bb7a4c251', version=0, score=0.96354645, payload={'image_path': '/home/arunchandra/Downloads/final/2672.jpg'}, vector=None, shard_key=None), ScoredPoint(id='cd8b879c-3763-45a8-bd27-874d9a1b9a5b', version=0, score=0.9619398, payload={'image_path': '/home/arunchandra/Downloads/final/3302.jpg'}, vector=None, shard_key=None), ScoredPoint(id='cc618d55-9fb2-4227-885e-6906923a0214', version=0, score=0.9610821, payload={'image_path': '/home/arunchandra/Downloads/final/3229.jpg'}, vector=None, shard_key=None), ScoredPoint(id='a9a1a249-0fae-4b40-9ca8-f29aadb6e6c6', version=0, score=0.9590177, payload={'image_path': '/home/arunchandra/Downloads/final/2718.jpg'}, vector=None, shard_key=None), ScoredPoint(id='23e172cd-6695-4881-ad36-63908bb951a0', version=0, score=0.9579815, payload={'image_path': '/home/arunchandra/Downloads/final/2869.jpg'}, vector=None, shard_key=None), ScoredPoint(id='03eadf80-c452-4302-a010-b4303d049008', version=0, score=0.9560898, payload={'image_path': '/home/arunchandra/Downloads/final/3651.jpg'}, vector=None, shard_key=None), ScoredPoint(id='4c952072-e49c-4d78-b2b4-2ca21292b1a2', version=0, score=0.95522994, payload={'image_path': '/home/arunchandra/Downloads/final/3648.jpg'}, vector=None, shard_key=None), ScoredPoint(id='c09eab11-1d9d-4090-84e4-bd7fd93d7379', version=0, score=0.9531991, payload={'image_path': '/home/arunchandra/Downloads/final/2103.jpg'}, vector=None, shard_key=None), ScoredPoint(id='abfb2a03-e2e7-4ee7-a46c-f2d5ae604623', version=0, score=0.9526864, payload={'image_path': '/home/arunchandra/Downloads/final/7169.jpg'}, vector=None, shard_key=None), ScoredPoint(id='8ef16596-9bcf-4ed2-aefa-2545a092b3cc', version=0, score=0.95214623, payload={'image_path': '/home/arunchandra/Downloads/final/2757.jpg'}, vector=None, shard_key=None), ScoredPoint(id='74a6ddb7-1504-474f-bd34-2c4624f71e41', version=0, score=0.95189846, payload={'image_path': '/home/arunchandra/Downloads/final/7171.jpg'}, vector=None, shard_key=None), ScoredPoint(id='30660ae2-7231-4355-a43e-a1d489ddf337', version=0, score=0.9518565, payload={'image_path': '/home/arunchandra/Downloads/final/2705.jpg'}, vector=None, shard_key=None), ScoredPoint(id='7c96f155-2fa5-492f-82bc-52d5356bfadb', version=0, score=0.951755, payload={'image_path': '/home/arunchandra/Downloads/final/2748.jpg'}, vector=None, shard_key=None), ScoredPoint(id='74ceb921-85a5-4019-8ecf-04aa952242c0', version=0, score=0.9515758, payload={'image_path': '/home/arunchandra/Downloads/final/2708.jpg'}, vector=None, shard_key=None), ScoredPoint(id='4c036338-0ad1-4338-8c86-c32e76862731', version=0, score=0.9511752, payload={'image_path': '/home/arunchandra/Downloads/final/7170.jpg'}, vector=None, shard_key=None), ScoredPoint(id='2959ec74-ab41-42fb-9c97-5d462949a792', version=0, score=0.9510301, payload={'image_path': '/home/arunchandra/Downloads/final/2749.jpg'}, vector=None, shard_key=None), ScoredPoint(id='509148c9-7640-4dcd-827e-7ec27e9b65d8', version=0, score=0.9507491, payload={'image_path': '/home/arunchandra/Downloads/final/2760.jpg'}, vector=None, shard_key=None), ScoredPoint(id='0f3da0cf-626a-4790-89eb-473d7800e1c2', version=0, score=0.95056534, payload={'image_path': '/home/arunchandra/Downloads/final/3199.jpg'}, vector=None, shard_key=None), ScoredPoint(id='b88061fe-c1a8-486a-a976-ad417a207bed', version=0, score=0.95051116, payload={'image_path': '/home/arunchandra/Downloads/final/5774.jpg'}, vector=None, shard_key=None), ScoredPoint(id='3352e73a-3477-4e4c-9759-836bfec3f010', version=0, score=0.94976765, payload={'image_path': '/home/arunchandra/Downloads/final/5758.jpg'}, vector=None, shard_key=None)]
# hit>> id='a24ec001-7029-48f5-b431-237bb7a4c251' version=0 score=0.96354645 payload={'image_path': '/home/arunchandra/Downloads/final/2672.jpg'} vector=None shard_key=None
# hit>> id='cd8b879c-3763-45a8-bd27-874d9a1b9a5b' version=0 score=0.9619398 payload={'image_path': '/home/arunchandra/Downloads/final/3302.jpg'} vector=None shard_key=None
# hit>> id='cc618d55-9fb2-4227-885e-6906923a0214' version=0 score=0.9610821 payload={'image_path': '/home/arunchandra/Downloads/final/3229.jpg'} vector=None shard_key=None
# hit>> id='a9a1a249-0fae-4b40-9ca8-f29aadb6e6c6' version=0 score=0.9590177 payload={'image_path': '/home/arunchandra/Downloads/final/2718.jpg'} vector=None shard_key=None
# hit>> id='23e172cd-6695-4881-ad36-63908bb951a0' version=0 score=0.9579815 payload={'image_path': '/home/arunchandra/Downloads/final/2869.jpg'} vector=None shard_key=None
# hit>> id='03eadf80-c452-4302-a010-b4303d049008' version=0 score=0.9560898 payload={'image_path': '/home/arunchandra/Downloads/final/3651.jpg'} vector=None shard_key=None
# hit>> id='4c952072-e49c-4d78-b2b4-2ca21292b1a2' version=0 score=0.95522994 payload={'image_path': '/home/arunchandra/Downloads/final/3648.jpg'} vector=None shard_key=None
# hit>> id='c09eab11-1d9d-4090-84e4-bd7fd93d7379' version=0 score=0.9531991 payload={'image_path': '/home/arunchandra/Downloads/final/2103.jpg'} vector=None shard_key=None
# hit>> id='abfb2a03-e2e7-4ee7-a46c-f2d5ae604623' version=0 score=0.9526864 payload={'image_path': '/home/arunchandra/Downloads/final/7169.jpg'} vector=None shard_key=None
# hit>> id='8ef16596-9bcf-4ed2-aefa-2545a092b3cc' version=0 score=0.95214623 payload={'image_path': '/home/arunchandra/Downloads/final/2757.jpg'} vector=None shard_key=None
# hit>> id='74a6ddb7-1504-474f-bd34-2c4624f71e41' version=0 score=0.95189846 payload={'image_path': '/home/arunchandra/Downloads/final/7171.jpg'} vector=None shard_key=None
# hit>> id='30660ae2-7231-4355-a43e-a1d489ddf337' version=0 score=0.9518565 payload={'image_path': '/home/arunchandra/Downloads/final/2705.jpg'} vector=None shard_key=None
# hit>> id='7c96f155-2fa5-492f-82bc-52d5356bfadb' version=0 score=0.951755 payload={'image_path': '/home/arunchandra/Downloads/final/2748.jpg'} vector=None shard_key=None
# hit>> id='74ceb921-85a5-4019-8ecf-04aa952242c0' version=0 score=0.9515758 payload={'image_path': '/home/arunchandra/Downloads/final/2708.jpg'} vector=None shard_key=None
# hit>> id='4c036338-0ad1-4338-8c86-c32e76862731' version=0 score=0.9511752 payload={'image_path': '/home/arunchandra/Downloads/final/7170.jpg'} vector=None shard_key=None
# hit>> id='2959ec74-ab41-42fb-9c97-5d462949a792' version=0 score=0.9510301 payload={'image_path': '/home/arunchandra/Downloads/final/2749.jpg'} vector=None shard_key=None
# hit>> id='509148c9-7640-4dcd-827e-7ec27e9b65d8' version=0 score=0.9507491 payload={'image_path': '/home/arunchandra/Downloads/final/2760.jpg'} vector=None shard_key=None
# hit>> id='0f3da0cf-626a-4790-89eb-473d7800e1c2' version=0 score=0.95056534 payload={'image_path': '/home/arunchandra/Downloads/final/3199.jpg'} vector=None shard_key=None
# hit>> id='b88061fe-c1a8-486a-a976-ad417a207bed' version=0 score=0.95051116 payload={'image_path': '/home/arunchandra/Downloads/final/5774.jpg'} vector=None shard_key=None
# hit>> id='3352e73a-3477-4e4c-9759-836bfec3f010' version=0 score=0.94976765 payload={'image_path': '/home/arunchandra/Downloads/final/5758.jpg'} vector=None shard_key=None
# Similar images: ['/home/arunchandra/Downloads/final/2672.jpg', '/home/arunchandra/Downloads/final/3302.jpg', '/home/arunchandra/Downloads/final/3229.jpg', '/home/arunchandra/Downloads/final/2718.jpg', '/home/arunchandra/Downloads/final/2869.jpg', '/home/arunchandra/Downloads/final/3651.jpg', '/home/arunchandra/Downloads/final/3648.jpg', '/home/arunchandra/Downloads/final/2103.jpg', '/home/arunchandra/Downloads/final/7169.jpg', '/home/arunchandra/Downloads/final/2757.jpg', '/home/arunchandra/Downloads/final/7171.jpg', '/home/arunchandra/Downloads/final/2705.jpg', '/home/arunchandra/Downloads/final/2748.jpg', '/home/arunchandra/Downloads/final/2708.jpg', '/home/arunchandra/Downloads/final/7170.jpg', '/home/arunchandra/Downloads/final/2749.jpg', '/home/arunchandra/Downloads/final/2760.jpg', '/home/arunchandra/Downloads/final/3199.jpg', '/home/arunchandra/Downloads/final/5774.jpg', '/home/arunchandra/Downloads/final/5758.jpg', '/media/arunchandra/local/Downloads/123.jpg']

# %% [markdown]
# #### Displaying Images Using Matplotlib
#
# - The last image is the input image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# List of image file paths
image_paths = similar_images

# Define the dimensions of the image matrix
rows = 5
cols = 5

# Create a figure to display the images
fig, axes = plt.subplots(rows, cols, figsize=(10, 5))

# Iterate over the image paths and plot them in the matrix
for i in range(rows):
    for j in range(cols):
        ax = axes[j] if rows == 1 else axes[i, j]
        img_idx = i * cols + j
        if img_idx < len(image_paths):
            img = mpimg.imread(image_paths[img_idx])
            ax.imshow(img)
        ax.axis('off')

# Display the plot
plt.tight_layout()
plt.show()
